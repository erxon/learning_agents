# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
groq_api_key = os.getenv('GROQ_API_KEY')

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:8]}")
else:
    print("Groq API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# Groq API Key exists and begins gsk_r65Z

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from groq import Groq

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

groq_client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Find the four‑digit number ABCD (with A ≠ 0) such that when multiplied by 4 the result is the number DCBA.

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let
#
# \[
# N = ABCD = 1000A+100B+10C+D\qquad (A\neq 0)
# \]
#
# and the condition is
#
# \[
# 4N = DCBA = 1000D+100C+10B+A .
# \]
#
# ---
#
# ### 1.  Work with the carries
#
# Multiplying the four‑digit number by 4 digit‑by‑digit gives the following system (with carries \(k_1,k_2,k_3\)):
#
# \[
# \begin{aligned}
# 4D &= A + 10k_1 ,\\[2pt]
# 4C + k_1 &= B + 10k_2 ,\\[2pt]
# 4B + k_2 &= C + 10k_3 ,\\[2pt]
# 4A + k_3 &= D .
# \end{aligned}
# \]
#
# Here \(k_1,k_2,k_3\) are the carries, each of which can be 0, 1, 2 or 3 (because \(4\times9+3=39\)).
#
# ---
#
# ### 2.  Determine \(A\) and \(D\)
#
# From the first and last equations
#
# \[
# A\equiv 4D \pmod{10},\qquad D = 4A + k_3 .
# \]
#
# Testing the nine possible non‑zero values of \(D\):
#
# | \(D\) | \(4D\) | \(A\) (units) | \(k_1\) |
# |------|--------|---------------|--------|
# | 1 | 4 | 4 | 0 |
# | 2 | 8 | 8 | 0 |
# | 3 | 12| 2 | 1 |
# | 4 | 16| 6 | 1 |
# | 5 | 20| 0 | 2 (reject, \(A\neq0\)) |
# | 6 | 24| 4 | 2 |
# | 7 | 28| 8 | 2 |
# | 8 | 32| 2 | 3 |
# | 9 | 36| 6 | 3 |
#
# Only the pair \((D,A)=(8,2)\) can satisfy the last equation, because then
#
# \[
# 4A + k_3 = 8 \Longrightarrow 8 + k_3 = 8 \Longrightarrow k_3 = 0 .
# \]
#
# All other pairs make \(4A+k_3\) far larger than a single digit.
#
# Thus
#
# \[
# D=8,\quad A=2,\quad k_1=3,\quad k_3=0 .
# \]
#
# ---
#
# ### 3.  Find \(B\) and \(C\)
#
# Now solve the middle two equations with \(k_1=3,\;k_3=0\):
#
# \[
# \begin{aligned}
# 4C + 3 &= B + 10k_2, \tag{1}\\
# 4B + k_2 &= C . \tag{2}
# \end{aligned}
# \]
#
# Because \(C\) is a digit, (2) forces \(4B + k_2 < 10\), so \(B\) can only be \(0,1,2\).
#
# * **\(B=0\):** then \(C=k_2\). Substituting in (1) gives \(4k_2+3 = 10k_2\), which has no integer solution.
#
# * **\(B=1\):** from (2) \(C = 4 + k_2\) (so \(k_2\le 3\)). Plug into (1):
#
#   \[
#   4(4+k_2)+3 = 1 + 10k_2 \Longrightarrow 19+4k_2 = 1+10k_2
#   \Longrightarrow 18 = 6k_2 \Longrightarrow k_2 = 3 .
#   \]
#
#   Hence \(C = 4+3 = 7\).
#
# * **\(B=2\):** then \(C = 8 + k_2\) which already exceeds a single digit for any admissible \(k_2\). No solution.
#
# Thus the only consistent digits are
#
# \[
# B = 1,\qquad C = 7,\qquad k_2 = 3 .
# \]
#
# ---
#
# ### 4.  The number
#
# \[
# N = ABCD = 2\,1\,7\,8 = 2178 .
# \]
#
# Checking:
#
# \[
# 4 \times 2178 = 8712 = \text{reverse of }2178 .
# \]
#
# Hence the required four‑digit number is
#
# \[
# \boxed{2178}.
# \]

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let
#
# \[
# N = ABCD = 1000A+100B+10C+D\qquad (A\neq 0)
# \]
#
# and the condition is
#
# \[
# 4N = DCBA = 1000D+100C+10B+A .
# \]
#
# ---
#
# ### 1.  Work with the carries
#
# Multiplying the four‑digit number by 4 digit‑by‑digit gives the following system (with carries \(k_1,k_2,k_3\)):
#
# \[
# \begin{aligned}
# 4D &= A + 10k_1 ,\\[2pt]
# 4C + k_1 &= B + 10k_2 ,\\[2pt]
# 4B + k_2 &= C + 10k_3 ,\\[2pt]
# 4A + k_3 &= D .
# \end{aligned}
# \]
#
# Here \(k_1,k_2,k_3\) are the carries, each of which can be 0, 1, 2 or 3 (because \(4\times9+3=39\)).
#
# ---
#
# ### 2.  Determine \(A\) and \(D\)
#
# From the first and last equations
#
# \[
# A\equiv 4D \pmod{10},\qquad D = 4A + k_3 .
# \]
#
# Testing the nine possible non‑zero values of \(D\):
#
# | \(D\) | \(4D\) | \(A\) (units) | \(k_1\) |
# |------|--------|---------------|--------|
# | 1 | 4 | 4 | 0 |
# | 2 | 8 | 8 | 0 |
# | 3 | 12| 2 | 1 |
# | 4 | 16| 6 | 1 |
# | 5 | 20| 0 | 2 (reject, \(A\neq0\)) |
# | 6 | 24| 4 | 2 |
# | 7 | 28| 8 | 2 |
# | 8 | 32| 2 | 3 |
# | 9 | 36| 6 | 3 |
#
# Only the pair \((D,A)=(8,2)\) can satisfy the last equation, because then
#
# \[
# 4A + k_3 = 8 \Longrightarrow 8 + k_3 = 8 \Longrightarrow k_3 = 0 .
# \]
#
# All other pairs make \(4A+k_3\) far larger than a single digit.
#
# Thus
#
# \[
# D=8,\quad A=2,\quad k_1=3,\quad k_3=0 .
# \]
#
# ---
#
# ### 3.  Find \(B\) and \(C\)
#
# Now solve the middle two equations with \(k_1=3,\;k_3=0\):
#
# \[
# \begin{aligned}
# 4C + 3 &= B + 10k_2, \tag{1}\\
# 4B + k_2 &= C . \tag{2}
# \end{aligned}
# \]
#
# Because \(C\) is a digit, (2) forces \(4B + k_2 < 10\), so \(B\) can only be \(0,1,2\).
#
# * **\(B=0\):** then \(C=k_2\). Substituting in (1) gives \(4k_2+3 = 10k_2\), which has no integer solution.
#
# * **\(B=1\):** from (2) \(C = 4 + k_2\) (so \(k_2\le 3\)). Plug into (1):
#
#   \[
#   4(4+k_2)+3 = 1 + 10k_2 \Longrightarrow 19+4k_2 = 1+10k_2
#   \Longrightarrow 18 = 6k_2 \Longrightarrow k_2 = 3 .
#   \]
#
#   Hence \(C = 4+3 = 7\).
#
# * **\(B=2\):** then \(C = 8 + k_2\) which already exceeds a single digit for any admissible \(k_2\). No solution.
#
# Thus the only consistent digits are
#
# \[
# B = 1,\qquad C = 7,\qquad k_2 = 3 .
# \]
#
# ---
#
# ### 4.  The number
#
# \[
# N = ABCD = 2\,1\,7\,8 = 2178 .
# \]
#
# Checking:
#
# \[
# 4 \times 2178 = 8712 = \text{reverse of }2178 .
# \]
#
# Hence the required four‑digit number is
#
# \[
# \boxed{2178}.
# \]

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that is worth exploring for an Agentic AI opportunity."}]

# Then make the first call:

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# **Business Area:** **Enterprise Supply‑Chain & Logistics Management**
#
# ---
#
# ### Why It’s a Prime Target for an Agentic AI Opportunity
#
# | Factor | What It Means for an Agentic AI | Business Impact |
# |--------|--------------------------------|-----------------|
# | **Complex, multi‑step workflows** | An autonomous “supply‑chain orchestrator” can plan, execute, and adapt end‑to‑end processes (procurement → production → shipping → fulfillment) without human micromanagement. | 10‑30 % cost reduction, faster time‑to‑market, fewer stock‑outs. |
# | **High‑value data (prices, demand forecasts, carrier schedules, IoT sensor streams)** | Agent can continuously ingest, reason over, and act on real‑time data, negotiating with vendors, rerouting shipments, and updating forecasts on the fly. | Improves forecast accuracy by 15‑25 % and reduces inventory carrying costs. |
# | **Regulatory & compliance pressure** | Built‑in policy engines let the agent enforce trade‑compliance, customs rules, carbon‑footprint caps, and ESG reporting automatically. | Avoids fines, meets sustainability targets, and builds brand trust. |
# | **Stakeholder coordination across silos** | Multi‑agent ecosystem (procurement‑agent, production‑agent, logistics‑agent, finance‑agent) can negotiate contracts, share constraints, and settle conflicts autonomously. | Cuts coordination overhead, reduces decision latency from days to minutes. |
# | **Margin‑sensitive industry** | Even modest efficiency gains translate into large dollar gains for manufacturers, retailers, and distributors. | Direct bottom‑line uplift and competitive advantage. |
#
# ---
#
# ### A Concrete Agentic AI Concept: **Supply‑Chain Autonomous Orchestrator (SCAO)**
#
# | Component | Core Capabilities | Example Actions |
# |-----------|-------------------|-----------------|
# | **Perception Layer** | Real‑time ingestion of ERP data, IoT sensor feeds, market price APIs, weather & geopolitical alerts. | Detect a 20 % surge in raw‑material price in China; spot a container delay due to a storm. |
# | **Reasoning & Planning Layer** | Goal‑oriented planning (minimize total cost while meeting service‑level targets), constraint solving, Monte‑Carlo risk simulation. | Re‑optimize the production schedule to shift a batch to a lower‑cost plant; simulate impact of carrier disruption. |
# | **Negotiation Agents** | Multi‑party automated bargaining (e‑procurement, freight contracts, inventory borrowing). Uses game‑theoretic models + LLM‑driven proposal generation. | Secure a 5 % discount on a bulk purchase; renegotiate a carrier’s surcharge in exchange for volume commitment. |
# | **Execution Layer** | API‑driven actions on ERP, TMS, WMS, and external marketplaces; robotic process automation for order entry, invoicing, and customs filing. | Auto‑issue a purchase order, book a freight slot, trigger a customs filing, and update inventory levels. |
# | **Compliance & ESG Guardrails** | Policy engine with formal rules (e.g., “no sourcing from blacklisted entities”, “carbon budget ≤ X t CO₂ per quarter”). | Block a supplier flagged for labor violations; reroute shipments to a lower‑emission mode when carbon budget is tight. |
# | **Feedback & Learning Loop** | Continuous reinforcement‑learning from KPI outcomes (OTIF, cost, carbon), human‑in‑the‑loop overrides, explainable‑AI dashboards. | Adjust cost‑weighting in the objective function after a quarterly review. |
#
# ---
#
# ### Value Proposition (Bottom‑Line Numbers)
#
# | Metric | Baseline (Typical Industry) | Expected Post‑Deployment | Driver |
# |--------|----------------------------|--------------------------|--------|
# | **Total Supply‑Chain Cost** | 12 % of revenue | ↓ 8‑10 % | Dynamic sourcing, freight optimization, inventory reduction |
# | **Order‑to‑Delivery Lead Time** | 12 days | ↓ 30‑45 % | Real‑time rerouting, auto‑re‑scheduling |
# | **On‑Time‑In‑Full (OTIF)** | 92 % | ↑ 96‑98 % | Predictive disruption handling |
# | **Carbon Emissions (Scope 3)** | 1.2 t CO₂ per $M shipped | ↓ 10‑20 % | Carbon‑aware routing, modal shift |
# | **Human Labor Hours on Routine Tasks** | 400 h/month | ↓ 60‑80 % | End‑to‑end automation of order entry, invoicing, compliance checks |
#
# *Even a conservative 5 % cost reduction on a $1 bn supply‑chain spend translates to $50 M annual savings.*
#
# ---
#
# ### Go‑to‑Market Playbook
#
# | Phase | Key Activities | Success Criteria |
# |-------|----------------|------------------|
# | **1️⃣ Discovery & Data‑Fit** | Map existing ERP/TMS/WMS APIs; pilot data pipelines on a single product line. | >95 % data coverage, latency <5 s. |
# | **2️⃣ MVP – “Negotiation‑Agent”** | Deploy a procurement‑agent that auto‑generates RFQs and evaluates supplier bids using LLM‑driven language understanding. | 15‑20 % faster RFQ cycle, 3 % price improvement. |
# | **3️⃣ Full Orchestrator** | Add production‑ and logistics‑agents; integrate risk‑simulation engine. | 10 % cost cut, OTIF ≥ 96 % across pilot sites. |
# | **4️⃣ Scale & ESG Layer** | Encode carbon‑budget constraints; roll out across all product families and regions. | Carbon reduction ≥ 10 % and compliance audit pass. |
# | **5️⃣ Platform Offering** | Package as a SaaS “Supply‑Chain Autonomous Orchestrator” for mid‑large manufacturers and 3PLs (subscription + usage‑based pricing). | $5‑10 M ARR in Year 2, churn < 5 %. |
#
# ---
#
# ### Risks & Mitigations
#
# | Risk | Mitigation |
# |------|------------|
# | **Data quality / siloed systems** | Start with a “data‑fabric” layer (graph DB + CDC) that normalizes across ERP/TMS. Provide adapters for legacy systems. |
# | **Regulatory / compliance breaches** | Formal policy engine with audit trails; human‑in‑the‑loop approvals for high‑risk actions. |
# | **Trust & Explainability** | Generate “decision‑cards” (LLM‑summarized rationale + simulation results) for every autonomous action. |
# | **Supplier pushback on automated negotiation** | Offer a “negotiation‑sandbox” where suppliers can set acceptable terms; the agent respects those boundaries. |
# | **Cybersecurity** | Zero‑trust API gateway, role‑based access, end‑to‑end encryption, and continuous red‑team testing. |
#
# ---
#
# ## TL;DR
#
# **Supply‑chain & logistics management** is a high‑value, data‑rich, decision‑heavy domain where an **autonomous, multi‑agent AI orchestrator** can deliver 10‑30 % cost savings, faster deliveries, and measurable ESG benefits. Building a modular SCAO that starts with a negotiation‑agent and expands to full end‑to‑end orchestration gives a clear path from pilot to a scalable commercial SaaS platform.

# %%
messages = [{"role": "user", "content": f"{business_idea}, According to this response, present a pain-point in this industry. Something challenging that might be ripe for agentic solution."}]

# Then make the first call:

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=messages
)

# Then read the business idea:

pain_point = response.choices[0].message.content

from IPython.display import Markdown, display

display(Markdown(pain_point))
# Out:
# ### A Core Pain‑Point that Screams “Agentic AI Needed”
#
# #### **Dynamic Disruption Management & Real‑Time Re‑Orchestration**
#
# **What the problem looks like today**
#
# | Dimension | Typical Situation | Why it’s painful |
# |-----------|-------------------|------------------|
# | **Data volume & velocity** | Thousands of IoT sensor streams (temperature, location, vibration), carrier schedule feeds, market‑price APIs, weather & geopolitical alerts pour in every minute. | Human planners cannot ingest, correlate, and act on this flood fast enough. |
# | **Decision latency** | When a container is delayed (e.g., a port strike, a storm, a customs hold), the “last‑minute” response is a manual email chain that takes **12‑48 h** to converge on a new plan. | Every hour of delay multiplies the cost of late‑delivery penalties, expediting fees, and lost sales. |
# | **Multi‑stakeholder impact** | A single disruption ripples across procurement, production scheduling, warehouse staffing, carrier contracts, and finance (cash‑flow). | Coordination requires **multiple meetings**, spreadsheets, and ad‑hoc spreadsheets—high error risk and hidden costs. |
# | **Risk quantification** | Companies run “what‑if” spreadsheets after the fact, estimating the cost of a disruption **days** later. | No proactive mitigation; the organization reacts *after* the damage is done. |
# | **Compliance & ESG constraints** | Sudden reroutes may violate carbon‑budget caps, customs restrictions, or trade‑embargo rules. | Manual checks are error‑prone; a compliance breach can trigger fines and reputational damage. |
#
# **Bottom‑line impact**
#
# - **Lost service‑level revenue:** 1–3 % of annual sales per major disruption (missed OTIF, back‑order penalties).
# - **Expedited freight & inventory surge:** $0.5‑$2 M per incident for a mid‑size manufacturer.
# - **Human‑resource cost:** 30‑50 h of senior planner time per event (≈ $3‑$5 k).
#
# > **In short:** The *speed* at which the supply‑chain must detect, evaluate, and execute a new plan far exceeds human capabilities, creating a chronic “reaction‑only” operating model that burns money and erodes customer trust.
#
# ---
#
# #### Why an **Agentic AI** is the natural remedy
#
# 1. **Continuous perception & correlation** – autonomous agents can ingest all real‑time feeds, fuse them into a unified “disruption graph,” and flag a problem the instant a sensor deviation or external alert appears.
# 2. **Goal‑directed planning under constraints** – using a probabilistic planner (e.g., Monte‑Carlo tree search + constraint‑programming) the agent can instantly generate *feasible* alternative routes, production schedules, and procurement actions that respect cost, lead‑time, carbon‑budget, and trade‑compliance rules.
# 3. **Negotiation & execution** – a logistics‑agent can automatically renegotiate freight contracts, request spot‑capacity, or trigger a backup carrier, while a procurement‑agent places a rush purchase order with a vetted alternate supplier. All actions are executed via API calls to ERP/TMS/WMS without a human clicking “send.”
# 4. **Explainable, human‑in‑the‑loop overrides** – the agent surfaces a concise “decision card” (risk‑score, cost impact, ESG impact, confidence interval) that senior planners can approve with a single click—or let the system auto‑approve low‑risk moves.
# 5. **Learning & improvement** – reinforcement‑learning loops compare the *actual* outcome (cost saved, OTIF restored) to the projected impact, continuously refining the disruption‑response policy.
#
# ---
#
# #### A concrete scenario (illustrative)
#
# | Event | Human‑only workflow (current) | Agentic‑AI workflow (future) |
# |-------|------------------------------|-----------------------------|
# | **Port strike announced** (30 % of inbound containers delayed) | 1️⃣ Planner receives email → 2️⃣ Checks affected PO list (manual spreadsheet) → 3️⃣ Calls suppliers for alternate shipments → 4️⃣ Calls carriers to find space → 5️⃣ Updates ERP, re‑runs MPS → 6️⃣ Sends revised delivery dates to sales → 7️⃣ Verifies compliance (carbon, customs). **Total latency:** 18‑36 h. | 1️⃣ Real‑time news feed triggers disruption graph → 2️⃣ Agent simulates impact on all downstream orders → 3️⃣ Auto‑generates alternate sourcing plan (nearest qualified supplier, price, ETA) → 4️⃣ Negotiates spot‑rate with carriers via API → 5️⃣ Executes PO & freight booking → 6️⃣ Updates ERP, sends auto‑generated email to customers → 7️⃣ Compliance guardrail auto‑checks carbon budget. **Total latency:** 3‑5 min (with optional human sign‑off). |
#
# **Result:** Cost of expediting freight drops from $500 k to <$30 k; OTIF stays > 96 %; no compliance breach; planner freed for strategic work.
#
# ---
#
# ### Bottom line
#
# **Dynamic disruption management**—the need to sense, evaluate, and re‑orchestrate an entire supply‑chain in seconds rather than hours—is a *pain‑point* that is:
#
# - **Quantifiable** (millions in avoidable cost per year).
# - **Data‑rich** (feeds already exist, they just aren’t orchestrated).
# - **High‑impact** (affects cost, service, ESG, and regulatory risk simultaneously).
# - **Hard for humans** (requires multi‑domain expertise, real‑time reasoning, and rapid execution).
#
# Because it is precisely the kind of **multi‑step, high‑stakes, data‑driven workflow** that agentic AI excels at, building a **Disruption‑Response Agent** (the first “micro‑agent” in a broader Supply‑Chain Autonomous Orchestrator) offers an immediate, defensible, and revenue‑generating foothold for any AI‑first venture in enterprise supply‑chain & logistics.

# %%
messages = [{"role": "user", "content": f"{pain_point}. According to this pain point, propose an Agentic AI Solution"}]

# Then make the first call:

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=messages
)

# Then read the business idea:

solution = response.choices[0].message.content

from IPython.display import Markdown, display

display(Markdown(solution))
# Out:
# ## **Agentic AI Solution – “Dynamic Disruption‑Response Agent (DDRA)”**
# *A purpose‑built, autonomous software‑agent that continuously watches the supply‑chain, reasons about the impact of any disruption, and instantly re‑orchestrates the end‑to‑end plan while keeping humans in the loop for high‑‑risk decisions.*
#
# ---
#
# ### 1️⃣  Solution Vision (One‑Sentence Pitch)
#
# > **DDRA** is an *autonomous, goal‑directed AI‑agent* that turns every stream of real‑time supply‑chain data into a live “disruption graph”, runs constrained‑optimisation in seconds, and executes the optimal mitigation actions through existing ERP/TMS/WMS APIs – delivering < 5 min response times, ≥ 95 % OTIF preservation, and > $1 M annual cost avoidance for a mid‑size manufacturer.
#
# ---
#
# ## 2️⃣  Core Architecture
#
# | Layer | Function | Key Technologies & Open‑Source Options |
# |-------|----------|----------------------------------------|
# | **Perception & Ingestion** | Pulls > 10 k events/min from IoT, ERP, external APIs, news feeds, social‑media, satellite weather, customs alerts. | • Apache Kafka + Kafka Streams (event bus)  <br>• Confluent Schema Registry (Avro/Protobuf)  <br>• ksqlDB for low‑latency filtering  <br>• Edge‑gateway micro‑services for MQTT/OPC-UA sensor streams |
# | **Fusion & Knowledge‑Graph** | Normalises, timestamps, enriches, and stores events as a **Temporal Disruption Graph (TDG)** – a property graph where nodes = assets (containers, trucks, PO, supplier) and edges = relationships (belongs‑to, scheduled‑to, capacity‑link). | • Neo4j Aura or Amazon Neptune (graph DB)  <br>• Temporal extensions (t‑graph)  <br>• Apache Spark Structured Streaming for batch‑side enrichment |
# | **Situational Awareness Engine** | Detects anomalies, infers “disruption patterns”, scores urgency. | • LSTM/Temporal‑CNN on sensor streams (PyTorch)  <br>• BERT‑based news‑event classifier (HuggingFace)  <br>• Probabilistic causal inference (DoWhy)  <br>• Scoring: Risk = P(impact ≥ threshold) × cost impact |
# | **Goal‑Directed Planner** | Generates *feasible* alternative plans that satisfy multi‑objective constraints (cost, lead‑time, carbon, trade, capacity). | • **Hybrid Planner**  <br>   - Monte‑Carlo Tree Search (MCTS) for stochastic scenario sampling  <br>   - Constraint‑Programming (OR‑Tools CP‑SAT) for hard constraints  <br>   - Differentiable optimisation (Optuna + Pyomo) for cost‑gradient fine‑tuning  <br>• Policy‑network (Transformer) that proposes top‑K candidate actions to prune the search space |
# | **Decision‑Card Generator (Explainable UI)** | Summarises *what*, *why*, *how* in < 2 min reading time; attaches confidence intervals, ESG impact, and a “auto‑approve” flag. | • LLM‑based summariser (OpenAI‑GPT‑4‑Turbo or locally‑hosted Llama‑3‑70B) with Retrieval‑Augmented Generation (RAG)  <br>• Visualisation: Plotly‑Dash + Neo4j Bloom embedded in a web UI  <br>• Auditable provenance log (Kafka Log‑Compaction) |
# | **Execution & Negotiation Agents** | Turns the chosen plan into concrete API calls, renegotiates freight, creates PO, triggers warehouse moves, updates customs docs. | • **Logistics Agent** – interacts with TMS (e.g., project44, FourKites) via REST/GraphQL  <br>• **Procurement Agent** – SAP Ariba, Coupa, or custom ERP API  <br>• **Compliance Guardrail Service** – rule‑engine (Drools) that validates carbon‑budget, embargoes, HS‑code restrictions  <br>• **Message‑Broker** (Kafka) for reliable, exactly‑once execution |
# | **Learning & Feedback Loop** | Measures actual outcomes (cost saved, OTIF restored) vs. projected; updates models. | • RL‑style credit assignment (Off‑policy Q‑learning)  <br>• Counterfactual reasoning via Causal Forests  <br>• Model registry (MLflow) and continuous‑training pipelines (Kubeflow) |
# | **Security, Governance & Compliance** | Ensures data privacy, role‑based access, auditability. | • Zero‑Trust Service Mesh (Istio)  <br>• Vault for secret management  <br>• GDPR/CCPA‑compliant data masking  <br>• SOC‑2 & ISO‑27001 controls baked into CI/CD pipelines |
#
# > **Deployment Model:** Containerised micro‑services (Docker + Kubernetes) with *blue‑green* rollout capabilities; can be run on‑prem (for regulated data) or in a VPC‑isolated cloud (AWS/GCP/Azure).
#
# ---
#
# ## 3️⃣  End‑to‑End Workflow (15‑second “reaction loop”)
#
# | Step | Agent Action | Data / Output |
# |------|--------------|---------------|
# | **0 – Continuous Ingestion** | Sensors, carrier schedules, market price feeds, news APIs push events to Kafka. | Raw event stream |
# | **1 – Fusion** | TDG updates: new node **Port‑Strike‑Alert** with timestamp, location, affected vessels. | Updated graph |
# | **2 – Anomaly Detection** | LSTM flags a *significant deviation* (> 30 % drop in inbound vessel ETA) → Risk Score = 0.86. | Disruption alert |
# | **3 – Impact Propagation** | Graph traversal computes downstream PO set (≈ 1 200 items) and associated revenue at risk ($3.4 M). | Impact model |
# | **4 – Scenario Generation** | MCTS samples 5,000 stochastic futures (weather, carrier capacity). | Candidate plans |
# | **5 – Constraint Solving** | CP‑SAT prunes to **3** feasible plans meeting: <br>• ≤ $250 k additional freight cost <br>• ≤ 2 % carbon‑budget increase <br>• Compliance‑clear. | Feasible plan set |
# | **6 – Scoring & Selection** | Multi‑objective utility = 0.45 × cost‑saving – 0.30 × delay hrs – 0.25 × CO₂‑increase. Plan #2 highest utility. | Recommended plan |
# | **7 – Decision Card** | LLM produces a 3‑paragraph card: <br>• *What*: reroute 400 TEU via XYZ port, source 20 % from Supplier‑B. <br>• *Why*: saves $210 k, restores 96 % OTIF, respects carbon cap. <br>• *How*: auto‑book spot‑capacity, generate PO, notify customers. | Human‑review UI (auto‑approve if risk < 0.4) |
# | **8 – Execution** | Logistics Agent calls carrier API → books 400 TEU spot‑capacity; Procurement Agent creates rush PO to Supplier‑B; Compliance Guardrail validates ESG. | Transaction IDs, updated ERP/TMS records |
# | **9 – Monitoring** | Real‑time telemetry feeds back into TDG; RL agent logs reward (cost saved $210 k, OTIF +2 %). | Feedback data |
# | **10 – Learning** | Model update: adjust cost‑impact coefficients; policy‑network fine‑tuned with latest reward. | New model version (auto‑promoted after validation) |
#
# **Total wall‑clock latency:** **~3‑5 minutes** (including human “click‑to‑approve” optional step).
#
# ---
#
# ## 4️⃣  Business Value & ROI (Illustrative for a Mid‑Size Manufacturer)
#
# | Metric | Current (Human‑Only) | With DDRA (Year 1) | Comments |
# |--------|----------------------|-------------------|----------|
# | **Average disruption response time** | 18‑36 h | 3‑5 min | 99 % reduction |
# | **Expedited freight cost per incident** | $0.5‑$2 M | $30‑$80 k | 95 % cost cut |
# | **OTIF loss per incident** | 2‑4 % | < 0.2 % | Revenue protection |
# | **Planner‑time saved** | 30‑50 h/event → $3‑5 k | 0 h (auto) | Re‑allocate to strategic work |
# | **Annual avoided disruption cost** | – | **$1.2 M** (conservative) | Based on 6 major incidents / yr |
# | **ESG compliance risk** | Manual checks → 0.5 % breach probability | Guardrail → < 0.05 % | Avoid fines & brand damage |
# | **Implementation cost (Year 0)** | – | $1.2 M (cloud + dev + integration) | 12 months rollout |
# | **Payback period** | – | **≈ 10 months** | 3× ROI by end of Year 1 |
#
# > **Sensitivity:** Even a 30 % reduction in response time yields > $400 k savings per incident for a $5 M freight spend; the model scales linearly with volume.
#
# ---
#
# ## 5️⃣  Productisation Roadmap
#
# | Phase | Duration | Key Deliverables | Success Criteria |
# |-------|----------|------------------|------------------|
# | **0 – Discovery & Data‑Fit** | 4 wks | • Inventory of data sources <br>• Data‑quality audit <br>• Security & compliance scoping | ≥ 90 % of required feeds ingested in sandbox |
# | **1 – MVP – “Alert‑to‑Plan”** | 12 wks | • Perception pipeline (Kafka + Fusion) <br>• Simple rule‑based disruption detection <br>• CP‑SAT planner for *single* constraint (cost) <br>• Decision‑card UI (read‑only) | < 15 min end‑to‑end response on a simulated port strike |
# | **2 – Agentic Core + Execution** | 16 wks | • Hybrid planner (MCTS + CP‑SAT) <br>• Logistics & Procurement execution agents (API connectors) <br>• Auto‑approve workflow <br>• Audit log & provenance | < 5 min response, 80 % of actions executed without manual steps |
# | **3 – Multi‑Objective & ESG Guardrails** | 12 wks | • Carbon‑budget, embargo, customs rule engine (Drools) <br>• LLM‑driven decision cards (explainability) <br>• Human‑in‑the‑loop UI for high‑risk (> 0.5 risk) moves | Zero compliance violations in test, 95 % decision‑card approval rate |
# | **4 – Learning Loop & Scaling** | 12 wks | • RL reward pipeline <br>• Model‑registry & CI/CD (Kubeflow) <br>• Horizontal scaling to 10 k events/s | Continuous improvement > 5 % cost‑saving per quarter |
# | **5 – Production & Managed Service** | Ongoing | • SLA‑driven SaaS offering (multi‑tenant) or on‑prem white‑label <br>• 24×7 monitoring & support <br>• Quarterly business review dashboards | > 99.5 % uptime, < 2 % manual overrides per month |
#
# **Total Time‑to‑Value:** **≈ 8 months** from contract signing to production for a pilot customer.
#
# ---
#
# ## 6️⃣  Integration Touch‑Points (What the Customer Already Has)
#
# | Existing System | Integration Pattern | Sample API Call |
# |-----------------|--------------------|-----------------|
# | **ERP (SAP S/4, Oracle, Microsoft Dynamics)** | Event‑driven (Kafka → SAP OData) + Command (POST `/PurchaseOrder`) | `POST https://sap.company.com/odata/v2/PO` |
# | **TMS / Visibility (project44, FourKites)** | Real‑time schedule sync (WebSocket) + Spot‑booking (REST) | `POST https://api.project44.com/v2/booking` |
# | **WMS (Manhattan, Blue Yonder)** | Inventory push/pull (gRPC) | `grpc UpdateInventory(request)` |
# | **Supplier Portals / E‑procurement (Ariba, Coupa)** | Purchase‑order creation via API key | `POST https://api.coupa.com/api/purchase_orders` |
# | **External Feeds (weather, news, customs)** | Pull via HTTP/REST + Pub‑Sub (AWS SNS) | `GET https://api.weather.com/v3/alerts` |
# | **Carbon‑tracking platform (e.g., EcoVadis, SAP Emissions Management)** | Validation webhook (POST) | `POST https://emissions.company.com/validate` |
#
# All connectors are **thin adapters** (≈ 100 LOC each) that translate standard JSON/Avro to the internal event schema; they can be generated automatically from OpenAPI specs.
#
# ---
#
# ## 7️⃣  Explainability & Trust (Why Humans Will Adopt It)
#
# 1. **Provenance Graph** – every recommendation is linked to the exact set of input events (sensor reading, news article, price spike) and the model version that produced it. Clicking a node shows raw data.
# 2. **Confidence Intervals** – Monte‑Carlo simulation yields a 95 % CI on cost impact; the UI highlights “high‑uncertainty” actions that require manual sign‑off.
# 3. **Rule‑Based Override Layer** – business policies (e.g., “Never exceed 5 % carbon budget increase”) are encoded in a deterministic Drools rule set that *must* be satisfied before any plan is offered.
# 4. **Human‑Feedback Capture** – every “approve”, “reject”, or “edit” is logged and fed back to the RL reward function, ensuring the agent learns the organization’s risk appetite.
# 5. **Audit Trail** – immutable Kafka log (log‑compaction) + digital signatures (HashiCorp Vault) enable forensic review for regulators.
#
# ---
#
# ## 8️⃣  Security, Privacy & Governance
#
# | Concern | Mitigation |
# |---------|------------|
# | **Data‑in‑Transit** | Mutual TLS between all micro‑services; mTLS for external API calls. |
# | **Data‑at‑Rest** | Encryption‑at‑rest (AES‑256) for Kafka topics, Neo4j, object storage (S3‑KMS). |
# | **Least‑Privilege Access** | Role‑Based Access Control (RBAC) in Istio; separate service‑accounts per agent. |
# | **Compliance** | GDPR‑compliant data‑subject request pipeline; ISO‑27001 aligned processes; audit logs shipped to a SIEM (Splunk/Elastic). |
# | **Model‑Integrity** | Model signing via HashiCorp Vault; CI pipeline enforces “no‑untrusted‑model” gate. |
# | **Business Continuity** | Multi‑region Kafka replication; active‑active Neo4j clusters; automated fail‑over scripts. |
#
# ---
#
# ## 9️⃣  Competitive Landscape & Differentiation
#
# | Competitor | What they offer | Gap |
# |------------|----------------|-----|
# | **Traditional TMS/ERP add‑ons** (e.g., SAP Advanced Planning) | Rule‑based re‑planning, batch‑run optimization (hours). | No real‑time perception; no autonomous execution; limited ESG constraints. |
# | **AI‑only “Predictive Analytics” vendors** (e.g., ClearMetal) | Forecast demand, recommend routes (offline). | Not an *agent*; human still manually executes. |
# | **Robotic Process Automation (RPA)** | Automates UI clicks for order updates. | RPA cannot *reason* under uncertainty; fragile to UI changes. |
# | **Full‑stack Autonomous Supply‑Chain platforms** (e.g., Project44’s “Control Tower”) | Visualization + alerts. | Still relies on human planners for decision & execution. |
# | **Our DDRA** | **End‑to‑end perception → reasoning → execution**, multi‑objective constrained optimisation, built‑in ESG guardrails, explainable decision cards, reinforcement learning loop. | **True agency** – the system *acts* on its own when risk is low, otherwise *asks* with a concise rationale. |
#
# ---
#
# ## 10️⃣  Go‑to‑Market & Business Model
#
# | Offering | Pricing | Target Segment | Value‑Added Services |
# |----------|---------|----------------|----------------------|
# | **SaaS “Disruption‑Response as a Service”** | $2 k / month per 5 k events + $0.10 per automated transaction | Mid‑size manufacturers, 3PLs, large distributors | 24×7 monitoring, quarterly model‑tuning, compliance audit reports |
# | **On‑Prem / Private‑Cloud White‑Label** | License $250 k + annual support $75 k | Regulated industries (pharma, aerospace) | Dedicated account team, custom rule‑engine extensions |
# | **Professional Services** | $200‑$300 / hour (implementation, data‑onboarding) | All | Data‑pipeline engineering, custom ML model training, integration with legacy ERP. |
#
# **Early‑adopter incentives:** 6‑month free “pilot‑run” (up to 2 M events) with a guaranteed **$250 k cost‑avoidance** credit or refund.
#
# ---
#
# ## 11️⃣  Summary – Why DDRA Is the *Agentic AI* Answer to the Pain‑Point
#
# | Pain‑Point | DDRA Capability | Outcome |
# |------------|----------------|---------|
# | **Flood of heterogeneous real‑time data** | Continuous perception pipeline + Temporal Disruption Graph | Human‑readable, instantly searchable view of every event. |
# | **Decision latency (12‑48 h)** | Hybrid Monte‑Carlo + CP‑SAT planner delivers feasible alternatives in < 5 min. | Faster mitigation, lower penalty costs. |
# | **Multi‑stakeholder coordination** | Execution agents talk to TMS, ERP, procurement, ESG platforms via APIs; single “decision card” replaces email chains. | One click replaces dozens of emails/meetings. |
# | **Post‑mortem risk quantification** | Causal inference & RL reward logging provides *real* impact numbers *during* the event. | Proactive risk budgeting, better insurance pricing. |
# | **Compliance & ESG constraints** | Drools guardrails + carbon‑budget validator enforce hard rules before any action. | Zero compliance breaches, ESG goals met. |
# | **Human‑in‑the‑loop trust** | Explainable UI, provenance, confidence intervals, override policy. | Adoption > 90 % after 2 weeks of pilot. |
#
# **Bottom line:** DDRA converts the chaotic, reaction‑only supply‑chain into a **self‑steering ecosystem** that perceives, decides, and acts at machine speed while keeping humans informed and in control of high‑risk moves—exactly the kind of *agentic AI* that delivers quantifiable, repeatable ROI in a market desperate for speed and resilience.
#
# ---
#
# **Next step:**
# Schedule a 45‑minute technical deep‑dive where we can map **your exact data sources** to the ingestion layer, prototype a **disruption‑graph** on a subset of your IoT feeds, and co‑design the **first “quick‑win” scenario** (e.g., carrier capacity shortage).
#
# *Let’s turn every disruption into an opportunity for automated, profit‑preserving action.*
